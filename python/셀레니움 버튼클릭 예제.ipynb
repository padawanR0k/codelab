# %%
from selenium import webdriver
import time
browser = webdriver.Chrome('./chromedriver_mac')
browser.get('https://www.tpirates.com/main');
time.sleep(1)
browser.find_element_by_link_text('시장').click()
time.sleep(2)
browser.find_element_by_id('searchZoneCode').click()
browser.find_element_by_class_name('targetItem0000000002_0').click()
browser.find_element_by_id('sorting').click()
browser.find_element_by_class_name('targetItempopularity').click()
time.sleep(1)
print(browser.page_source)
# Out:
# <html lang="ko" class="BROWSER-CHROME BROWSER-VERSION83 PLATFORM-MACINTOSH PAGETYPE-M RANDERTYPE-P" data-_root="https://www.tpirates.com/"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1"><title>인어교주해적단 - 노량진수산시장, 가락시장 회센터, 부산 자갈치시장, 속초수산시장 가격 정보</title><link rel="canonical" href="https://www.tpirates.com/시장"><meta name="viewport" content="initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,width=device-width" id="meta-viewport"><meta name="format-detection" content="telephone=no"><meta name="url" content="https://www.tpirates.com/시장" id="meta-url"><meta name="author" content="인어교주해적단" id="meta-author"><meta name="subject" content="인어교주해적단 - 노량진수산시장, 가락시장 회센터, 부산 자갈치시장, 속초수산시장 가격 정보" id="meta-title"><meta name="description" content="노량진수산시장, 가락시장 회센터, 가락시장 회센터, 부산 자갈치시장, 속초수산시장, 대게, 킹크랩, 랍스터 시세, 꽃게, 전복, 도다리 가격 등 전국 수산시장의 다양한 수산물 시세를 제공합니다." id="meta-description"><meta name="thumbnail" content="https://cdn.tpirates.com/img/ci_logo.gif" id="meta-thumbnail"><meta property="fb:app_id" content="1563461907244524"><meta property="og:site_name" content="인어교주해적단"><meta property="og:title" content="인어교주해적단 - 노량진수산시장, 가락시장 회센터, 부산 자갈치시장, 속초수산시장 가격 정보"><meta property="og:type" content="article"><meta property="og:url" content="https://www.tpirates.com/시장"><meta property="og:image" content="https://cdn.tpirates.com/img/ci_logo.gif"><meta property="og:locale" content="ko_KR"><meta property="og:description" content="노량진수산시장, 가락시장 회센터, 가락시장 회센터, 부산 자갈치시장, 속초수산시장, 대게, 킹크랩, 랍스터 시세, 꽃게, 전복, 도다리 가격 등 전국 수산시장의 다양한 수산물 시세를 제공합니다."><link rel="stylesheet" href="https://www.tpirates.com/css/extention/jquery.ui_1.11.0.min.css?v=33586620bab1d02173f3cb9827c8cfee" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/extention/page_1.0.0.css?v=a7517ca4e4c5e282fb3a54f9630f3302" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/extention/swiper_4.4.1.min.css?v=26c92f1366428c2942321b2b8eecd909" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/base.css?v=4a4d6f7f7caca974d90e1ed0ff0e5bf2" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/common.css?v=177b8aa0c09932296ee91b1180f7da66" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/layout.css?v=e36eff68ad3f57519fb224436c14bacf" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/store.css?v=0799edad05935577f3a45c3a52682b99" media="all" type="text/css"><link rel="stylesheet" href="https://www.tpirates.com/css/adjustment.css?v=7cee1436a95adce8a5677071b6d9eb83" media="all" type="text/css"><script async="" src="//www.google-analytics.com/analytics.js"></script><script src="https://www.tpirates.com/js/extention/jquery_1.10.2.min.js?v=10746c0a32c194f32df354c994fafab5" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/jquery.ui_1.11.0.min.js?v=52d681d4dd2305755508829aaf7bd0d4" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/clipboard_1.7.1.min.js?v=3e5e0fa949e0e7c5ed5fed7b4cc0ee00" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/form_3.40.min.js?v=a2452646e71e1415d64fe6b855a0b12f" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/lazy_1.7.10.min.js?v=41dacb2afb62f64ac2c4bf32a79a6da8" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/validation_1.11.1.min.js?v=a046533229308e3c0dc84c4ce9cca11f" type="text/javascript"></script><script src="https://www.tpirates.com/js/extention/swiper_4.4.1.min.js?v=317fd00903b68a157500b40495e8d74e" type="text/javascript"></script><script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script><script>var kakakoApiJavascriptCode = "895803de3cd6807f5d5e2fcc6159e595"</script><script src="https://www.tpira ...
#     "@context" : "http://schema.org",
#     "@type" : "Organization",
#     "name" : "인어교주해적단",
#     "url" : "https://www.tpirates.com/",
#     "sameAs" : [
#         "https://smartstore.naver.com/tpirates",
#         "https://www.facebook.com/tpirates/",
#         "https://blog.naver.com/ostwee",
#         "https://www.youtube.com/channel/UCWq4TrLFdm7fFzCb4uo2V4Q",
#         "https://www.instagram.com/tpirates2013/",
#         "https://play.google.com/store/apps/details?id=com.tpirates.tpiratesapp",
#         "https://apps.apple.com/kr/app/인어교주해적단/id1051182256",
#         "https://goto.kakao.com/@인어교주해적단"
#     ]
# }</script><!-- End Schema.org --><script>var analyticsLink="/시장";var analyticsHash = window.location.hash;if(!IsBlank(analyticsHash)){analyticsLink+=analyticsHash;}analyticsLink+=GetAnalyticsSearchParamater("1");(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-62874395-1','auto');ga('send', 'pageview',analyticsLink);</script><!-- End Google GA Code --></head><body id="list" class="stores" contenteditable="false" style=""><!-- Google Tag Manager (noscript) --><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NFT9WBG" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><!-- End Google Tag Manager (noscript) --><div id="wrap" class="wrap"><!-- #header --><div id="header" class="header"><div class="colgroup fixed"><div class="ci use-search-reset">
# 			<a href="https://www.tpirates.com/" class=""><em class="img-menu ci-logo"></em><h1 class="img-menu ci-company-name">인어교주해적단</h1></a>
# 		</div><div class="gnb" id="gnb"><ul><li><a href="" class="use-modal-login">로그인/가입</a></li></ul></div><div class="lnb fixed" id="lnb"><ul><li class="on use-search-reset"><a href="https://www.tpirates.com/시장" title="시장" class="body_white_15_bold use-search-reset">시장</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/맛집" title="맛집" class="body_white_15_bold use-search-reset">맛집</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/온라인" title="온라인" class="body_white_15_bold use-search-reset">온라인</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/도매" title="도매" class="body_white_15_bold use-search-reset">도매</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/시세" title="시세" class="body_white_15_bold use-search-reset">시세</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/스페셜" title="스페셜" class="body_white_15_bold use-search-reset">스페셜</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/회스타그램" title="후기" class="body_white_15_bold use-search-reset">후기</a></li><li class=" use-search-reset"><a href="https://www.tpirates.com/문의" title="문의" class="body_white_15_bold use-search-reset">문의</a></li></ul></div></div></div><!-- //#header --><!-- #container --><div id="container" class="container"><div class="colgroup"><!-- content --><div id="content" class="content fixed"><div class="head">
#     <div class="section widget fixed" id="widget"><ul><li class="use-roll activate" data-view-zone-status-code="0" data-view-zone="[&quot;&quot;]" style="top: 0px;"><a href="https://www.tpirates.com/노량진수산시장부안수산" class="use-widget-count" data-targetcode="0000002716"><span class="body_white_14_bold">노량진:&nbsp;참치모듬회(소)&nbsp;</span><span class="txt-price body_green_14_bold">80,000원-&gt;64,000원</span><span class="body_white_14_bold">&nbsp;(쿠폰할인가)</span></a></li><li class="use-roll" data-view-zone-status-code="0" data-view-zone="[&quot;&quot;]"><a href="https://www.tpirates.com/노량진수산시장경성상회" class="use-widget-count" data-targetcode="0000002719"><span class="body_white_14_bold">노량진:&nbsp;돌돔회(중)&nbsp;</span><span class="txt-price body_green_14_bold">160,000원-&gt;112,000원</span><span class="body_white_14_bold">&nbsp;(주말특가할인)</span></a></li><li class="use-roll activate" data-view-zone-status-code="0" data-view-zone="[&quot;&quot;]" style="top: 42px;"><a href="https://www.tpirates.com/소래포구종합어시장지원이네" class="use-widget-count" data-targetcode="0000002715"><span class="body_white_14_bold">인천:&nbsp;줄전갱이모듬회(소)&nbsp;</span><span class="txt-price body_green_14_bold">60,000원-&gt;54,000원</span><span class="body_white_14_bold">&nbsp;(주말특가할인)</span></a></li></ul><em class="img-bul btn-arrow white arrow-down"></em></div>    <div class="section search-filter" id="search-filter">
#         <div class="filter-area">
#             <dl class="filter zone" id="searchZoneCode">
#                 <dt><span class="body_blue_14">노량진 ▾</span></dt>
#                 <dd>
#                     <div class="fixed filter-main">
#                         <table class="tbl-layout">
#                         <tbody>
#                             <tr>
#                             <td colspan="2" class="targetItem use-all"><span class="">모든지역</span></td><td colspan="2" class="targetItem targetItemnear near" data-target-data="near"><span>가까운 순</span></td><td colspan="2" class="targetItem targetItem0000000002_0 on" data-target-data="0000000002_0" data-serialize-text="노량진"><span class="body_gray_14_bold">노량진</span></td></tr><tr><td colspan="2" class="targetItem targetItem0000000004_0" data-target-data="0000000004_0" data-serialize-text="마포"><span>마포</span></td><td colspan="2" class="targetItem targetItem0000000005_0" data-target-data="0000000005_0" data-serialize-text="강서"><span>강서</span></td><td colspan="2" class="targetItem targetItem0000000003_0" data-target-data="0000000003_0" data-serialize-text="가락"><span>가락</span></td></tr><tr><td colspan="2" class="targetParentItem parent-0000000027 use-open-child" data-target-class="child-0000000027"><span>인천</span></td><td colspan="2" class="targetItem targetItem0000000036_0" data-target-data="0000000036_0" data-serialize-text="수원"><span>수원</span></td><td colspan="2" class="targetItem targetItem0000000034_0" data-target-data="0000000034_0" data-serialize-text="평촌"><span>평촌</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0" data-target-data="0000000027_0" data-serialize-text="인천 전체"><span>전체</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000235" data-target-data="0000000027_0000000235"><span>강화도양도어판장 </span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000236" data-target-data="0000000027_0000000236"><span>강화도분오어판장</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000234" data-target-data="0000000027_0000000234"><span>강화도외포항젓갈수산시장</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000232" data-target-data="0000000027_0000000232"><span>강화도선수포구어판장</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000231" data-target-data="0000000027_0000000231"><span>강화도선두5리어판장</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000227" data-target-data="0000000027_0000000227"><span>강화도황산도어판장</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000291" data-target-data="0000000027_0000000291"><span>구읍뱃터어시장</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000204" data-target-data="0000000027_0000000204"><span>영흥수협회센터</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000155" data-target-data="0000000027_0000000155"><span>영종관광어시장</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000146" data-target-data="0000000027_0000000146"><span>영흥수산물직판장어부들</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000145" data-target-data="0000000027_0000000145"><span>영흥수산물직판장</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000008" data-target-data="0000000027_0000000008"><span>인천종합(연안부두)어시장</span></td><td colspan="3" class="targetItem targetItem0000000027_0000000313" data-target-data="0000000027_0000000313"><span>인천종합(연안부두)갑각류센터</span></td></tr><tr class="tr-child child-0000000027 hide" data-parent-code="0000000027"><td colspan="3" class="targetItem targetItem0000000027_0000000007" data-target-data="0000000027_0000000007"><span>소래포구종합어시장</span></td><td colspan="3" class=""><span></span></td></tr><tr><td colspan="2" class="targetItem targetItem0000000035_0" data-target-data="0000000035_0" dat ...
#                         </tbody>
#                         </table>
#                     </div>
#                 </dd>
#             </dl>
#             <dl class="filter item" id="searchItemGroupCode">
#                 <dt><span class="body_blue_14">모든품목 ▾</span></dt>
#                 <dd>
#                     <div class="fixed filter-main">
#                         <table class="tbl-layout">
#                         <tbody>
#                             <tr>
#                             <td class="targetItem use-all"><span class="body_gray_14_bold">모든품목</span></td>
#                             <td class="targetItem targetItem0000000038" data-target-data="0000000038"><span>생선/횟감</span></td><td class="targetItem targetItem0000000040" data-target-data="0000000040"><span>생선/비횟감</span></td></tr><tr><td class="targetItem targetItem0000000039" data-target-data="0000000039"><span>게, 새우류</span></td><td class="targetItem targetItem0000000041" data-target-data="0000000041"><span>조개, 전복류</span></td><td class="targetItem targetItem0000000043" data-target-data="0000000043"><span>낙지, 문어류</span></td></tr><tr><td class="targetItem targetItem0000000042" data-target-data="0000000042"><span>멍게, 해삼류</span></td><td class="targetItem targetItem0000000047" data-target-data="0000000047"><span>김, 미역류</span></td><td class="targetItem targetItem0000000045" data-target-data="0000000045"><span>건어물</span></td></tr><tr><td class="targetItem targetItem0000000046" data-target-data="0000000046"><span>젓갈, 게장류</span></td><td class="targetItem targetItem0000000048" data-target-data="0000000048"><span>육류</span></td><td class="targetItem targetItem0000000066" data-target-data="0000000066"><span>상차림식당</span></td></tr><tr><td class="targetItem targetItem0000000065" data-target-data="0000000065"><span>기타</span></td><td class="targetItem"><span></span></td><td class="targetItem"><span></span></td>                            </tr>
#                         </tbody>
#                         </table>
#                     </div>
#                 </dd>
#             </dl>
#             <dl class="filter sort single" id="sorting">
#                 <dt><span class="body_blue_14">
#                 기본 순 ▾                </span></dt>
#                 <dd>
#                     <div class="fixed filter-main">
#                         <table class="tbl-layout">
#                         <tbody>
#                             <tr>
#                                 <td class="targetItem use-all" data-target-data=""><span class="body_gray_14_bold">기본 순</span></td>
#                             </tr>
#                             <tr>
#                                 <td class="targetItem targetItempopularity" data-target-data="popularity"><span>인기 순</span></td>
#                             </tr>
#                             <tr>
#                                 <td class="targetItem targetItemhistory" data-target-data="history"><span>최근 본 가게</span></td>
#                             </tr>
#                         </tbody>
#                         </table>
#                     </div>
#                 </dd>
#             </dl>
#         </div>
#         <div class="fixed search" id="searchText">
#             <input type="text" class="text-field search-text wpc100 input-guide body-lightgray_14 txt-input-guide" title="검색어를 입력하세요." value=""><button type="button" class="btn search body-lightlightgray_14">검색</button>
#         </div>
#     </div>
#     <div id="search-result" class="section flat hide"></div>
# </div>
# <div class="main" id="searchList" data-type="1" data-page-cut-length="20"><div class="section-title2 bg-spot"><h3 class="body_blue_14_bold">오늘의 추천 가게</h3></div><div class="fixed bg-spot pb5"><div class="bg-spot swiper-container swiper-level type1 swiper-container-horizontal"><div class="swiper-wrapper" style="transition-duration: 0ms; transform: translate3d(-388px, 0px, 0px);"><div class="section card-template type1 swiper-slide swiper-slide-duplicate swiper-slide-prev" data-swiper-slide-index="9" style="width: 388px;"><div class="fixed inner-section type1 use-hyperlink" data-href="https://www.tpirates.com/서귀포올레시장통큰수산"><div class="inner-inner-section type2"><span class="name body_gray_14_bold txt-ellipsis">통큰수산<span class="market body_gray_13 ml5">서귀포올레시장</span></span><span class="subject body_lightgray_13 txt-ellipsis">제주도 자연산 횟감을 저렴하게 맛볼 수 있는 횟집</span></div><div class="inner-inner-section type3"><span class="rating-summary body_orange_13_bold " id="rating-summary">★ 5.0</span><span class="business-status body_blue_13 txt-ellipsis ">영업 중</span></div></div><div class="fixed inner-section type2 use-hyperlink" data-href="https://www.tpirates.com/서귀포올레시장통큰수산"><span class="img-block store-img"><img src="https://cdn.tpirates.com/files/etc/2018/1120/25591e975eb7557641cf485d956c90bd_FThumb.jpg"></span><span class="favorite img-bul use-modal-login" data-targetcode="0000000149" data-membercode="" data-type="1"></span><div class="tag use-tag-overflow" data-type="1"><ul><li class="single-tag yesterday-price body_white_12 use-hyperlink" data-href="https://www.tpirates.com/서귀포올레시장통큰수산" style="width: 54px;">전일시세</li><li class="body_white_12" style="width: 39px;">#돌돔</li><li class="body_white_12" style="width: 50px;">#능성어</li><li class="body_white_12" style="width: 50px;">#자바리</li><li class="body_white_12" style="width: 60px;">#다금바리</li><li class="body_white_12" style="width: 39px;">#광어</li><li class="body_white_12 hide" style="">#우럭</li><li class="body_white_12 hide">#참돔</li><li class="body_white_12 hide">#벵에돔</li><li class="body_white_12 hide">#쥐치</li><li class="body_white_12 hide">#제주도</li></ul></div></div></div><div class="section card-template type1 swiper-slide swiper-slide-active" data-swiper-slide-index="0" style="width: 388px;"><div class="fixed inner-section type1 use-hyperlink" data-href="https://www.tpirates.com/가락시장경기축산"><div class="inner-inner-section type2"><span class="name body_gray_14_bold txt-ellipsis">경기축산<span class="market body_gray_13 ml5">가락시장</span></span><span class="subject body_lightgray_13 txt-ellipsis">가락몰 1+,1++등급 한우 전문 점포(가락몰 축산동 59호)</span></div><div class="inner-inner-section type3"><span class="rating-summary body_orange_13_bold " id="rating-summary">★ 4.5</span><span class="business-status body_blue_13 txt-ellipsis ">영업 중</span></div></div><div class="fixed inner-section type2 use-hyperlink" data-href="https://www.tpirates.com/가락시장경기축산"><span class="img-block store-img"><img src="https://cdn.tpirates.com/files/etc/2018/0905/e5ae1900f6a2f197b6d7d0fbb4c59674_FThumb.jpg"></span><span class="favorite img-bul use-modal-login" data-targetcode="0000000206" data-membercode="" data-type="1"></span><div class="tag use-tag-overflow" data-type="1"><ul><li class="single-tag today-price body_white_12 use-hyperlink" data-href="https://www.tpirates.com/가락시장경기축산" style="width: 54px;">오늘시세</li><li class="body_white_12" style="width: 39px;">#한우</li><li class="body_white_12" style="width: 50px;">#꽃등심</li><li class="body_white_12" style="width: 50px;">#토시살</li><li class="body_white_12" style="width: 50px;">#삼겹살</li><li class="body_white_12" style="width: 39px;">#목살</li><li class="body_white_12 hide" style="">#양갈비</li><li class="body_white_12 hide">#치마살</li><li class="body_white_12 hide">#항정살</li><li class="body_white_12 hide">#채끝살</li><li class="body_white_12 hide">#흑돼지</li><li class="body_white_12 hide">#차돌박이</li><li class="body_white_12 hide">#꽃갈비살</li><li class="body_white_12 hide">#살치살</li><li class="body_white_12 hide">#우 ...
# <div class="footer-nav-area"><div id="footerNavBack" class="footer-nav top use-page-top"></div></div></div><!-- //content --></div></div><!-- //#container --><div class="ajax-loading"><div class="loading-spinner"></div></div></div></body></html>

# %%
ti

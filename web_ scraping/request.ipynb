# %%
import requests

response = requests.get("https://www.dogdrip.net")
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="ko">\n<head>\n<!-- META -->\n<meta charset="utf-8">\n<meta name="generator" content="Rhymix">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="keywords" content="\xec\x9c\xa0\xeb\xa8\xb8, \xec\x9d\xb4\xec\x8a\x88, \xec\xa0\x95\xeb\xb3\xb4 \xec\xbb\xa4\xeb\xae\xa4\xeb\x8b\x88\xed\x8b\xb0. \xea\xb0\x9c\xeb\x93\x9c\xeb\xa6\xbd" />\n<meta name="description" content="\xec\x9c\xa0\xeb\xa8\xb8, \xec\x9d\xb4\xec\x8a\x88, \xec\xa0\x95\xeb\xb3\xb4 \xec\xbb\xa4\xeb\xae\xa4\xeb\x8b\x88\xed\x8b\xb0. \xea\xb0\x9c\xeb\x93\x9c\xeb\xa6\xbd" />\n<meta name="viewport" content="width=device-width, user-scalable=yes" />\n<meta name="theme-color" content="#2e4361" />\n<meta name="csrf-token" content="jcTr36bU0bh6SslG" />\n<!-- TITLE -->\n<title>DogDrip.Net \xea\xb0\x9c\xeb\x93\x9c\xeb\xa6\xbd</title>\n<!-- CSS -->\n<link rel="stylesheet" href="/files/cache/assets/compiled/a115db9af24ca711b6428c87de2f5a664cbb282b.rhymix.less.css?20200225171951" />\n<link re
# ...
